# %% [markdown]
# # <center><font size="6">$\color{blue}{\text{Project for COMP 6981}}$

# %% [markdown]
# <font size='6'>$\color{red}{\text{Task 1}}$

# %% [markdown]
# <font size='3.5'>
# The first part of your notebook must describe your dataset:<br>
#
# - This dataset is for 2240 observations (customers) with 28 variables related to marketing data. More specifically, the variables provide insights about:<br>
#     - Customer profiles<br>
#     - Products purchased<br>
#     - Campaign success (or failure)<br>
#     - Channel performance <br>
#
#
# - Start by describing your variables:<br>
#
#    - Id: $\hspace{5.7cm}$Customer's Unique Identifier <br>
#
#    - Year_Birth: $\hspace{4cm}$ Customer's Birth Year<br>
#
#    - Education: $\hspace{4.1cm}$Customer's education level <br>
#
#    - Maritial_status:  $\hspace{3.3cm}$Customer's marital status<br>
#
#    - income: $\hspace{4.4cm}~~$Customer's yearly household income<br>
#
#    - kidhome: $\hspace{4.4cm}$Number of children in customer's household <br>
#
#    - teenhome: $\hspace{4.1cm}$number of teenagers in costumers household <br>
#
#    - Dt_Customer: $\hspace{3.5cm}$Date of customer's enrollment with the company<br>
#
#    - Recency: $\hspace{4.4cm}$Number of days since customer's last purchase <br>
#
#    - MntWines: $\hspace{4.1cm}$Amount spent on wine in the last 2 years <br>
#
#    - MntFruits: $\hspace{4.2cm}$Amount spent on meat in the last 2 years <br>
#
#    - MntFishProducts: $\hspace{2.75cm}$Amount spent on fish in the last 2 years<br>
#
#    - MntSweetProducts: $\hspace{2.35cm}$Amount spent on sweet in the last 2 years <br>
#
#    - MntGoldProds: $\hspace{3.25cm}$Amount spent on gold in the last 2 years <br>
#
#    - NumDealsPurchases: $\hspace{2.1cm}$Number of deal Purchase <br>
#
#    - NumWebPurchases: $\hspace{2.3cm}$Number of people who by with web <br>
#
#    - NumCatalogPurchases: $\hspace{1.7cm}$Number of purchases made using a catalogue <br>
#
#    - NumStorePurchases: $\hspace{2.1cm}$Number of purchases made directly in stores<br>
#
#    - NumWebVisitsMonth: $\hspace{2cm}$Number of visits to company's web site in the last month<br>
#
#    - AcceptedCmp1: $\hspace{3cm}$1 if customer accepted the offer in the 1st campaign, 0 otherwise (Target variable) <br>
#
#    - AcceptedCmp2: $\hspace{3cm}$1 if customer accepted the offer in the 2nd campaign, 0 otherwise (Target variable) <br>
#
#    - AcceptedCmp3: $\hspace{3cm}$1 if customer accepted the offer in the 3rd campaign, 0 otherwise (Target variable) <br>
#
#    - AcceptedCmp4: $\hspace{3cm}$1 if customer accepted the offer in the 4th campaign, 0 otherwise (Target variable) <br>
#
#    - AcceptedCmp5: $\hspace{3cm}$1 if customer accepted the offer in the 5th campaign, 0 otherwise (Target variable) <br>
#
#    - Response: $\hspace{4.1cm}$1 if customer accepted the offer in the last campaign, 0 otherwise (Target variable) <br>
#
#    - Complain: $\hspace{4.1cm}$1 if customer complained in the last 2 years, 0 otherwise <br>
#
#    - Country: $\hspace{4.3cm}~$Customer's location<br><br>
#
#
# - You must generate attribute’s descriptors for all variables and discuss your results.<br>
#
#     - Provided inside <br>
#
# Income has a high positive correlation with "NumPurchases" columns and "Mnt" columns. This represents the High Income cluster and shows people with high income spend more and purchase more frequently. Income has a high negative correlation with "NumWebVisitsMonth" suggesting that customers with high income do not for web visits too often.
#
# "Amount Spent on Wines" has a high positive correlation with "NumCatalogPurchases" and "NumStorePurchases", and similarly, "Amount Spent on Meat products" has a very high positive correlation with "NumCatalogPurchases", suggesting that People generally buy Wines and Meat products through Catalogs.
#
# "NumWebVisitsMonth" shows no correlation with "NumWebPurchases". Instead, it shows a mild correlation with "NumDealsPurchases" which suggests that deals are an effective way of stimulating purchases on the website.
#
#
#
# - You must generate plots that can give hints about the data distribution and a discussion about the results must be done.<br>
#     - Plots provided inside<br>
#
#
# - The decision of any descriptor statistics or plots must be justified. You will lose marks if plots are made without any justification.<br>
#     - Provided inside context<br>
#
#
# - Does your data contain missing data? Are outliers present in your data?
#     - Yes, our dataset had outleirs upto 5%<br>
#     - dataset had missing just in one attributes, we made missing values in two other attributes more and up to 10%<br>
#
#
# - Make sure you remove the missing data rows and the outliers from your DataFrame.<br>
#     - all missing values and outliers removed in clean data section<br>

# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import  numpy as np
import warnings
import plotly.express as ex
import plotly.graph_objs as go
import plotly.figure_factory as ff
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from pandas.plotting import scatter_matrix
from sklearn.base import BaseEstimator
from sklearn.base import TransformerMixin
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from IPython.display import display
from tabulate import tabulate

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import Normalizer

from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import SGDClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import KFold
from sklearn.metrics import auc,roc_auc_score,roc_curve,recall_score,f1_score
from sklearn.model_selection import RepeatedKFold, cross_validate

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import RepeatedKFold, cross_val_score
from sklearn.feature_selection import chi2
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectKBest
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.feature_selection import mutual_info_classif


seed = 321


import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Importing data set

# %%
ds1=pd.read_csv('marketing_data.csv')
ds1.head(5)
# Out:
#       ID  Year_Birth   Education Marital_Status       Income  Kidhome  \
# 0   1826        1970  Graduation       Divorced  $84,835.00         0
# 1      1        1961  Graduation         Single  $57,091.00         0
# 2  10476        1958  Graduation        Married  $67,267.00         0
# 3   1386        1967  Graduation       Together  $32,474.00         1
# 4   5371        1989  Graduation         Single  $21,474.00         1
#
#    Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# 0         0     6/16/14        0       189  ...                  6
# 1         0     6/15/14        0       464  ...                  7
# 2         1     5/13/14        0       134  ...                  5
# 3         1  2005-11-14        0        10  ...                  2
# 4         0  2004-08-14        0         6  ...                  2
#
#    NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  \
# ...

# %% [markdown]
# ## General information from dataset

# %% [markdown]
# <font size='3.5'>Dataset contain 28 columns where 3 of them are object. our target is $\color{blue}{\text{Response}}$.

# %%
print('shape of data:\n',np.shape(ds1))
print('\n dataset heading:')
ds1.head(5)
# Out:
# shape of data:
#  (2240, 28)
#
#  dataset heading:
#       ID  Year_Birth   Education Marital_Status       Income  Kidhome  \
# 0   1826        1970  Graduation       Divorced  $84,835.00         0
# 1      1        1961  Graduation         Single  $57,091.00         0
# 2  10476        1958  Graduation        Married  $67,267.00         0
# 3   1386        1967  Graduation       Together  $32,474.00         1
# 4   5371        1989  Graduation         Single  $21,474.00         1
#
#    Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# 0         0     6/16/14        0       189  ...                  6
# 1         0     6/15/14        0       464  ...                  7
# 2         1     5/13/14        0       134  ...                  5
# 3         1  2005-11-14        0        10  ...                  2
# 4         0  2004-08-14        0         6  ...                  2
#
#    NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  \
# ...

# %%
ds1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   object
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %% [markdown]
# <font size='3.5'>We have missing value in "Income" column

# %% [markdown]
# <font size='3.5'>Our target is $\color{blue}{\text{Response}}$.

# %%
sns.countplot(x="Response", data=ds1)
ds1.loc[:,'Response'].value_counts()
# Out:
# 0    1906
# 1     334
# Name: Response, dtype: int64

# %% [markdown]
# <font size='3.5'> Object columns are seprated and unnecessary columns are droped and saved in ds.

# %%
ds=ds1.drop(['AcceptedCmp1','AcceptedCmp2','AcceptedCmp3','AcceptedCmp4','AcceptedCmp5','Dt_Customer'],axis=1)
df_hist=ds.drop(['Education','Marital_Status','Country'],axis=1)

# %%
ds.describe().transpose()
# Out:
#                       count         mean          std     min      25%  \
# ID                   2240.0  5592.159821  3246.662198     0.0  2828.25
# Year_Birth           2240.0  1968.805804    11.984069  1893.0  1959.00
# Kidhome              2240.0     0.444196     0.538398     0.0     0.00
# Teenhome             2240.0     0.506250     0.544538     0.0     0.00
# Recency              2240.0    49.109375    28.962453     0.0    24.00
# MntWines             2240.0   303.935714   336.597393     0.0    23.75
# MntFruits            2240.0    26.302232    39.773434     0.0     1.00
# MntMeatProducts      2240.0   166.950000   225.715373     0.0    16.00
# MntFishProducts      2240.0    37.525446    54.628979     0.0     3.00
# MntSweetProducts     2240.0    27.062946    41.280498     0.0     1.00
# MntGoldProds         2240.0    44.021875    52.167439     0.0     9.00
# NumDealsPurchases    2240.0     2.325000     1.932238     0.0     1.00
# ...

# %% [markdown]
# <font size='3.5'>Coorolation matrix

# %%
corr_matrix=ds.corr()
corr_matrix['Response'].sort_values(ascending=False)
# Out:
# Response               1.000000
# MntWines               0.247254
# MntMeatProducts        0.236335
# NumCatalogPurchases    0.220810
# NumWebPurchases        0.148730
# MntGoldProds           0.139850
# MntFruits              0.125289
# MntSweetProducts       0.117372
# MntFishProducts        0.111331
# NumStorePurchases      0.039363
# Year_Birth             0.021325
# NumDealsPurchases      0.002238
# Complain              -0.001707
# NumWebVisitsMonth     -0.003987
# ID                    -0.021968
# Kidhome               -0.080008
# Teenhome              -0.154446
# Recency               -0.198437
# Name: Response, dtype: float64

# %% [markdown]
# <font size='3.5'>Romiving characters from income column.

# %%
ds["Income"]
# Out:
# 0       $84,835.00
# 1       $57,091.00
# 2       $67,267.00
# 3       $32,474.00
# 4       $21,474.00
#            ...
# 2235    $66,476.00
# 2236    $31,056.00
# 2237    $46,310.00
# 2238    $65,819.00
# 2239    $94,871.00
# Name: Income, Length: 2240, dtype: object

# %%
ds["Income"]=ds["Income"].str.replace("$","")
ds["Income"]=ds["Income"].str.replace(",","")
ds["Income"]=ds["Income"].str.replace(".00","")
ds["Income"] = pd.to_numeric(ds["Income"])
ds["Income"]
# Out:
# 0       84835.0
# 1       57091.0
# 2       67267.0
# 3       32474.0
# 4       21474.0
#          ...
# 2235    66476.0
# 2236    31056.0
# 2237    46310.0
# 2238    65819.0
# 2239    94871.0
# Name: Income, Length: 2240, dtype: float64

# %% [markdown]
# ## checking for duplicate

# %% [markdown]
# <font size='3.5'>Checked for duplicates, there was not any.

# %%
duplicate = ds[ds.duplicated()]
duplicate
# Out:
# Empty DataFrame
# Columns: [ID, Year_Birth, Education, Marital_Status, Income, Kidhome, Teenhome, Recency, MntWines, MntFruits, MntMeatProducts, MntFishProducts, MntSweetProducts, MntGoldProds, NumDealsPurchases, NumWebPurchases, NumCatalogPurchases, NumStorePurchases, NumWebVisitsMonth, Response, Complain, Country]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# ## Checking outliers

# %% [markdown]
# <font size='3.5'>Checking outliers and also ploting some attributes to show outliers.

# %%
print()
print('            Boxplot and Hist diagram of some attributes before filling missing values and removing outliers')


plt.figure(figsize=(12,16),dpi=100)


ax=plt.subplot(4,2,1)
sns.boxplot(y=ds['Income'])
ax.set_xlabel('Income')
ax=plt.subplot(4,2,2)
sns.histplot(data=ds,x=ds['Income'])


ax=plt.subplot(4,2,3)
sns.boxplot(y=ds['MntWines'])
ax.set_xlabel('MntWines')
ax=plt.subplot(4,2,4)
sns.histplot(data=ds,x=ds['MntWines'])

ax=plt.subplot(4,2,5)
sns.boxplot(y=ds['MntMeatProducts'])
ax.set_xlabel('MntMeatProducts')
ax=plt.subplot(4,2,6)
sns.histplot(data=ds,x=ds['MntMeatProducts'])

ax=plt.subplot(4,2,7)
sns.boxplot(y=ds['MntSweetProducts'])
ax.set_xlabel('MntSweetProducts')
ax=plt.subplot(4,2,8)
sns.histplot(data=ds,x=ds['MntSweetProducts'])


plt.subplots_adjust(wspace=1.6)
plt.subplots_adjust(hspace=0.2)

plt.show()
# Out:
#             Boxplot and Hist diagram of some attributes before filling missing values and removing outliers

# %%
outliers=[]
def detect_outlier(data_1):
    
    threshold=4
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)
    
    
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
    return outliers

# %% [markdown]
# <font size='3.5'>We have upto 5% outliers.

# %%
for column_name in df_hist.columns:
    column = ds[column_name]
    outlier_datapoints = detect_outlier(column)
    print('Count of outliers in column ', column_name, ' is : ', len(outlier_datapoints))
# Out:
# Count of outliers in column  ID  is :  0
# Count of outliers in column  Year_Birth  is :  3
# Count of outliers in column  Income  is :  10
# Count of outliers in column  Kidhome  is :  10
# Count of outliers in column  Teenhome  is :  10
# Count of outliers in column  Recency  is :  10
# Count of outliers in column  MntWines  is :  10
# Count of outliers in column  MntFruits  is :  20
# Count of outliers in column  MntMeatProducts  is :  25
# Count of outliers in column  MntFishProducts  is :  29
# Count of outliers in column  MntSweetProducts  is :  38
# Count of outliers in column  MntGoldProds  is :  42
# Count of outliers in column  NumDealsPurchases  is :  61
# Count of outliers in column  NumWebPurchases  is :  65
# Count of outliers in column  NumCatalogPurchases  is :  69
# Count of outliers in column  NumStorePurchases  is :  69
# Count of outliers in column  NumWebVisitsMonth  is :  75
# Count of outliers in column  Response  is :  75
# ...

# %% [markdown]
# ## Genarating missing values

# %% [markdown]
# <font size='3.5'>As we had one attribute with missing value, so make missing values in two other attribute more here.

# %%
new1 = ds[['MntWines','MntFruits']]

# %%
p = 0.1 
mask = np.random.choice([True, False], size=new1.shape, p=[p,1-p])
df1 = new1.mask(mask)
df1
# Out:
#       MntWines  MntFruits
# 0        189.0      104.0
# 1          NaN        5.0
# 2        134.0       11.0
# 3         10.0        0.0
# 4          NaN       16.0
# ...        ...        ...
# 2235     372.0       18.0
# 2236       5.0       10.0
# 2237     185.0        2.0
# 2238     267.0       38.0
# 2239     169.0       24.0
#
# [2240 rows x 2 columns]

# %%
ds=ds.drop(['MntWines','MntFruits'],axis=1)

# %%
df=pd.concat([ds,df1],axis=1)
df
# Out:
#          ID  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome  Recency  MntMeatProducts  MntFishProducts  ...  \
# 0            0        0              379              111  ...
# ...

# %% [markdown]
# <font size='3.5'>Now we have missing values in 3 attribute.

# %%
def missing_values():
    missing = df.columns[df.isnull().any()].tolist()
    return missing

df[missing_values()].isnull().sum()
# Out:
# Income        24
# MntWines     225
# MntFruits    233
# dtype: int64

# %% [markdown]
# ## Checking zero values

# %%
for column_name in df.columns:
    column = df[column_name]
    count = (column == 0).sum()
    print('Count of zeros in column ', column_name, ' is : ', count)
# Out:
# Count of zeros in column  ID  is :  1
# Count of zeros in column  Year_Birth  is :  0
# Count of zeros in column  Education  is :  0
# Count of zeros in column  Marital_Status  is :  0
# Count of zeros in column  Income  is :  2
# Count of zeros in column  Kidhome  is :  1293
# Count of zeros in column  Teenhome  is :  1158
# Count of zeros in column  Recency  is :  28
# Count of zeros in column  MntMeatProducts  is :  1
# Count of zeros in column  MntFishProducts  is :  384
# Count of zeros in column  MntSweetProducts  is :  419
# Count of zeros in column  MntGoldProds  is :  61
# Count of zeros in column  NumDealsPurchases  is :  46
# Count of zeros in column  NumWebPurchases  is :  49
# Count of zeros in column  NumCatalogPurchases  is :  586
# Count of zeros in column  NumStorePurchases  is :  15
# Count of zeros in column  NumWebVisitsMonth  is :  11
# Count of zeros in column  Response  is :  1906
# Count of zeros in column  Complain  is :  2219
# ...

# %% [markdown]
# # Dataset ditribution plot

# %% [markdown]
# <font size='3.5'>Distribution p[lots anmd their results.

# %%
df.hist(figsize=(12,8), grid=True, layout=(5, 5), bins = 20);
plt.tight_layout()

# %% [markdown]
# ## Discriptive statistics for attributes

# %%
print()
print('                      Discriptive statistics of attributes before removing outliers')


plt.figure(figsize=(12,40),dpi=200)



ax=plt.subplot(12,2,1)
sns.boxplot(y=df['Year_Birth'])
ax.set_xlabel('Year_Birth')
ax=plt.subplot(12,2,2)
sns.histplot(data=df,x=df['Year_Birth'])


ax=plt.subplot(12,2,3)
sns.boxplot(y=df['Kidhome'])
ax.set_xlabel('Kidhome')
ax=plt.subplot(12,2,4)
sns.histplot(data=df,x=df['Kidhome'])



ax=plt.subplot(12,2,5)
sns.boxplot(y=df['Teenhome'])
ax.set_xlabel('Teenhome')
ax=plt.subplot(12,2,6)
sns.histplot(data=df,x=df['Teenhome'])

ax=plt.subplot(12,2,7)
sns.boxplot(y=df['Recency'])
ax.set_xlabel('Recency')
ax=plt.subplot(12,2,8)
sns.histplot(data=df,x=df['Recency'])


ax=plt.subplot(12,2,9)
sns.boxplot(y=df['MntFruits'])
ax.set_xlabel('MntFruits')
ax=plt.subplot(12,2,10)
sns.histplot(data=df,x=df['MntFruits'])

ax=plt.subplot(12,2,11)
sns.boxplot(y=df['MntMeatProducts'])
ax.set_xlabel('MntMeatProducts')
ax=plt.subplot(12,2,12)
sns.histplot(data=df,x=df['MntMeatProducts'])


ax=plt.subplot(12,2,13)
sns.boxplot(y=df['MntFishProducts'])
ax.set_xlabel('MntFishProducts')
ax=plt.subplot(12,2,14)
sns.histplot(data=df,x=df['MntFishProducts'])

ax=plt.subplot(12,2,15)
sns.boxplot(y=df['MntSweetProducts'])
ax.set_xlabel('MntSweetProducts')
ax=plt.subplot(12,2,16)
sns.histplot(data=df,x=df['MntSweetProducts'])


ax=plt.subplot(12,2,17)
sns.boxplot(y=df['MntGoldProds'])
ax.set_xlabel('MntGoldProds')
ax=plt.subplot(12,2,18)
sns.histplot(data=df,x=df['MntGoldProds'])

ax=plt.subplot(12,2,19)
sns.boxplot(y=df['NumDealsPurchases'])
ax.set_xlabel('NumDealsPurchases')
ax=plt.subplot(12,2,20)
sns.histplot(data=df,x=df['NumDealsPurchases'])

ax=plt.subplot(12,2,21)
sns.boxplot(y=df['Income'])
ax.set_xlabel('Income')
ax=plt.subplot(12,2,22)
sns.histplot(data=df,x=df['Income'])

ax=plt.subplot(12,2,23)
sns.boxplot(y=df['MntWines'])
ax.set_xlabel('MntWines')
ax=plt.subplot(12,2,24)
sns.histplot(data=df,x=df['MntWines'])


plt.subplots_adjust(wspace=1)
plt.subplots_adjust(hspace=0.2)

plt.show()
# Out:
#                       Discriptive statistics of attributes before removing outliers

# %% [markdown]
# ## Discriptive statistics table

# %%
print()
print('            Discriptive statistics table of attributes before removing outliers')


table = [['Year_Birth','{:.2f}'.format(df['Year_Birth'].mean()),
         '{:.6f}'.format(df['Year_Birth'].median()),
         '{:.6f}'.format(df['Year_Birth'].std()),
         '{:.6f}'.format(df['Year_Birth'].min()),
         '{:.6f}'.format(df['Year_Birth'].max()),
         '{:.6f}'.format(df['Year_Birth'].var())],
        
         
         ['Kidhome','{:.2f}'.format(df['Kidhome'].mean()),
         '{:.6f}'.format(df['Kidhome'].median()),
         '{:.6f}'.format(df['Kidhome'].std()),
         '{:.6f}'.format(df['Kidhome'].min()),
         '{:.6f}'.format(df['Kidhome'].max()),
         '{:.6f}'.format(df['Kidhome'].var())],
         
     
         
         ['Teenhome','{:.2f}'.format(df['Teenhome'].mean()),
         '{:.6f}'.format(df['Teenhome'].median()),
         '{:.6f}'.format(df['Teenhome'].std()),
         '{:.6f}'.format(df['Teenhome'].min()),
         '{:.6f}'.format(df['Teenhome'].max()),
         '{:.6f}'.format(df['Teenhome'].var())],
         
         
         ['Recency','{:.2f}'.format(df['Recency'].mean()),
         '{:.6f}'.format(df['Recency'].median()),
         '{:.6f}'.format(df['Recency'].std()),
         '{:.6f}'.format(df['Recency'].min()),
         '{:.6f}'.format(df['Recency'].max()),
         '{:.6f}'.format(df['Recency'].var())],
         
         
         
         ['MntFruits','{:.2f}'.format(df['MntFruits'].mean()),
         '{:.6f}'.format(df['MntFruits'].median()),
         '{:.6f}'.format(df['MntFruits'].std()),
         '{:.6f}'.format(df['MntFruits'].min()),
         '{:.6f}'.format(df['MntFruits'].max()),
         '{:.6f}'.format(df['MntFruits'].var())],
         
         
         ['MntMeatProducts','{:.2f}'.format(df['MntMeatProducts'].mean()),
         '{:.6f}'.format(df['MntMeatProducts'].median()),
         '{:.6f}'.format(df['MntMeatProducts'].std()),
         '{:.6f}'.format(df['MntMeatProducts'].min()),
         '{:.6f}'.format(df['MntMeatProducts'].max()),
         '{:.6f}'.format(df['MntMeatProducts'].var())],
         
        
         
         ['MntFishProducts','{:.2f}'.format(df['MntFishProducts'].mean()),
         '{:.6f}'.format(df['MntFishProducts'].median()),
         '{:.6f}'.format(df['MntFishProducts'].std()),
         '{:.6f}'.format(df['MntFishProducts'].min()),
         '{:.6f}'.format(df['MntFishProducts'].max()),
         '{:.6f}'.format(df['MntFishProducts'].var())],
         
         
         ['MntSweetProducts','{:.2f}'.format(df['MntSweetProducts'].mean()),
         '{:.6f}'.format(df['MntSweetProducts'].median()),
         '{:.6f}'.format(df['MntSweetProducts'].std()),
         '{:.6f}'.format(df['MntSweetProducts'].min()),
         '{:.6f}'.format(df['MntSweetProducts'].max()),
         '{:.6f}'.format(df['MntSweetProducts'].var())],
         
         
         ['MntGoldProds','{:.2f}'.format(df['MntGoldProds'].mean()),
         '{:.6f}'.format(df['MntGoldProds'].median()),
         '{:.6f}'.format(df['MntGoldProds'].std()),
         '{:.6f}'.format(df['MntGoldProds'].min()),
         '{:.6f}'.format(df['MntGoldProds'].max()),
         '{:.6f}'.format(df['MntGoldProds'].var())],
         
         
         ['NumDealsPurchases','{:.2f}'.format(df['NumDealsPurchases'].mean()),
         '{:.6f}'.format(df['NumDealsPurchases'].median()),
         '{:.6f}'.format(df['NumDealsPurchases'].std()),
         '{:.6f}'.format(df['NumDealsPurchases'].min()),
         '{:.6f}'.format(df['NumDealsPurchases'].max()),
         '{:.6f}'.format(df['NumDealsPurchases'].var())],
         
         
         ['Income','{:.2f}'.format(df['Income'].mean()),
         '{:.6f}'.format(df['Income'].median()),
         '{:.6f}'.format(df['Income'].std()),
         '{:.6f}'.format(df['Income'].min()),
         '{:.6f}'.format(df['Income'].max()),
         '{:.6f}'.format(df['Income'].var())],
         
         ['MntWines','{:.2f}'.format(df['MntWines'].mean()),
         '{:.6f}'.format(df['MntWines'].median()),
         '{:.6f}'.format(df['MntWines'].std()),
         '{:.6f}'.format(df['MntWines'].min()),
         '{:.6f}'.format(df['MntWines'].max()),
         '{:.6f}'.format(df['MntWines'].var())]
         
        ]
         

print(tabulate(table, headers=["","Mean","Median","std.","Min","Max","Variance"],tablefmt="grid"))
print('\n')
# Out:
#             Discriptive statistics table of attributes before removing outliers
# +-------------------+----------+----------+--------------+-------+--------+------------------+
# |                   |     Mean |   Median |         std. |   Min |    Max |         Variance |
# +===================+==========+==========+==============+=======+========+==================+
# | Year_Birth        |  1968.81 |   1970   |    11.9841   |  1893 |   1996 |    143.618       |
# +-------------------+----------+----------+--------------+-------+--------+------------------+
# | Kidhome           |     0.44 |      0   |     0.538398 |     0 |      2 |      0.289873    |
# +-------------------+----------+----------+--------------+-------+--------+------------------+
# | Teenhome          |     0.51 |      0   |     0.544538 |     0 |      2 |      0.296522    |
# +-------------------+----------+----------+--------------+-------+--------+------------------+
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Recency              2240 non-null   int64
#  8   MntMeatProducts      2240 non-null   int64
#  9   MntFishProducts      2240 non-null   int64
#  10  MntSweetProducts     2240 non-null   int64
#  11  MntGoldProds         2240 non-null   int64
#  12  NumDealsPurchases    2240 non-null   int64
#  13  NumWebPurchases      2240 non-null   int64
#  14  NumCatalogPurchases  2240 non-null   int64
# ...

# %% [markdown]
# <font size='6'>$\color{red}{\text{Task 2}}$

# %% [markdown]
# <font size='3.5'>
# The second part of your project will consist of exploring data scaling techniques. The following tasks must be performed in this part:<br>
#
# - Choose at least 3 data scaling techniques and discuss why you are testing them. At least one data scaling technique must change the attributes’ distribution.:<br> <br>
#
#
# - we are testing different scler because There are several ways to do feature scaling with different application such as:<br>
#     - This method centres the median value at zero and this method is robust to outliers.<br>
#     - or Maxabs find the absolute maximum value of the feature in the dataset
#  is sensitive to outliers.<br>
#     - min-max is prone to outliers.<br>
#     - normalization  changes the shape of the distribution of data.<br>
#     - logarithmic scales skewnes towards large values<br>
#     - we applied 5 data scaling techinques and log sclaer changed the distribution
#
#
# - Plot the result, side by side, of the original and the data scaling techniques. Discuss the figure.:<br>
#
#    - It has been done <br>

# %% [markdown]
# # Data scaling

# %% [markdown]
# ## MinMax Scaler

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

ndf=df_hist.drop(['Income','MntWines','MntFruits'],axis=1)

def plot_histograms_density(df, columns, df_transformed, fig_title):
    fig, axs = plt.subplots(len(columns),2,figsize=(16,40),constrained_layout=True)
    fig.suptitle(fig_title, fontsize=16)
    axs = axs.flatten()
    i = 0 
    for c in columns:
        ndf[c].hist(ax=axs[i], density=True) # normalizes the density
        ndf[c].plot.density(ax=axs[i], title=c)
        df_transformed[c].hist(ax=axs[i+1], density=True, stacked=True) # normalizes the density
        df_transformed[c].plot.density(ax=axs[i+1], title=str(c+'_transformed'))
        i+=2

val_cols_names = ['Year_Birth','Kidhome','Teenhome','Recency','MntMeatProducts','MntFishProducts',
                 'MntSweetProducts', 'MntGoldProds', 'NumDealsPurchases']

# transform the data
scaler = MinMaxScaler()
min_max_tdf = scaler.fit_transform(ndf)
min_max_tdf = pd.DataFrame(min_max_tdf, index=ndf.index, columns=ndf.columns)

plot_histograms_density(ndf, val_cols_names, min_max_tdf, 'MinMax Scaler')

# %% [markdown]
# ## Maxabs scaler

# %%
from sklearn.preprocessing import MaxAbsScaler
# transform the data
scaler = MaxAbsScaler()
maxabs_tdf = scaler.fit_transform(ndf)
maxabs_tdf = pd.DataFrame(maxabs_tdf, index=ndf.index, columns=ndf.columns)

plot_histograms_density(ndf, val_cols_names, maxabs_tdf, 'MaxAbs Scaler')

# %% [markdown]
# ## Robust scaler

# %%
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()
robust_tdf = scaler.fit_transform(ndf)
robust_tdf = pd.DataFrame(robust_tdf, index=ndf.index, columns=ndf.columns)

plot_histograms_density(ndf, val_cols_names, robust_tdf, 'Robust Scaler')

# %% [markdown]
# ## Quantile scaler

# %%
from sklearn.preprocessing import QuantileTransformer

# scaler = QuantileTransformer(n_quantiles=10, random_state=0)
scaler = QuantileTransformer(n_quantiles=10, random_state=0, output_distribution='normal')
qtl_tdf = scaler.fit_transform(ndf)
qtl_tdf = pd.DataFrame(qtl_tdf, index=ndf.index, columns=ndf.columns)

plot_histograms_density(ndf, val_cols_names, qtl_tdf, 'Quantile Scaler')

# %% [markdown]
# ## z-score scaler

# %%
from sklearn.preprocessing import Normalizer

scaler = Normalizer()
zscore_tdf = scaler.fit_transform(ndf)
zscore_tdf = pd.DataFrame(zscore_tdf, index=ndf.index, columns=ndf.columns)

plot_histograms_density(ndf, val_cols_names, zscore_tdf, 'Z-score Scaler')

# %% [markdown]
# ## log scaler

# %%
from sklearn.preprocessing import FunctionTransformer
import numpy as np

scaler = FunctionTransformer(np.log1p)
log_tdf = scaler.fit_transform(ndf)
log_tdf = pd.DataFrame(log_tdf, index=ndf.index, columns=ndf.columns)

plot_histograms_density(ndf, val_cols_names, log_tdf, 'Log Scaler')

# %% [markdown]
# ## Scalers effect on data

# %%
def plot_histograms_density_for_scalers(df, columns, fig_title, scalers, scaler_names):
    fig, axs = plt.subplots(len(columns),len(scalers)+1,figsize=(16,18),constrained_layout=True)
    fig.suptitle(fig_title, fontsize=16)
    axs = axs.flatten()
    i = 0 
    for c in columns:
        ndf[c].hist(ax=axs[i], density=True) # normalizes the density
        ndf[c].plot.density(ax=axs[i], title=c)
        i+=1
        for j in range(len(scalers)):
            df_transformed = scalers[j].fit_transform(df)
            df_transformed = pd.DataFrame(df_transformed, index=df.index, columns=df.columns)
            df_transformed[c].hist(ax=axs[i], density=True, stacked=True) # normalizes the density
            df_transformed[c].plot.density(ax=axs[i], title=scaler_names[j])
            i+=1
            

scaler_names = ['MinMax', 'Z-score', 'MaxAbs', 'Robust', 'Quantile', 'Log']
arr_scalers = [MinMaxScaler(), Normalizer(), MaxAbsScaler(), RobustScaler(), QuantileTransformer(n_quantiles=10, random_state=0, output_distribution='normal'),FunctionTransformer(np.log1p)]
plot_histograms_density_for_scalers(ndf, val_cols_names, 'Scalers effect on data', arr_scalers, scaler_names)

# %% [markdown]
# <font size='6'>$\color{red}{\text{Task 3}}$

# %% [markdown]
# <font size='3.5'>
# - The third part of your project must advance your pre-processing strategy to handle the missing data and outliers selected in Part 1.<br>
#     - missing values replaced and outliers have been removed<br>
#
#
#
# - Choose one technique provided by pandas for filling missing data (e.g., bfill, ffill, etc) and fill the missing data. Plot the data and discuss potential problems with it.<br>
#     - we used ffile and linear forward methods to filling missing vaslue<br>
#
#
#
# - Create models using the two classifiers or regressors discussed in class (e.g., linear or KNN). Validate them and decide which one must be chosen. You must decide the best combination Classifier, Regressor + Data scaling technique. Discuss why you chose the combination. Don’t forget to justify which evaluation metric you will use to make such a decision.<br>
#
#     - as our model was classifier, we used KNN and SGD classifiers combination of 6 data scaling methods in this sectioin<br>
#     - SGD with Maxabs, for except z_score combination all other combination show good results.
#
#
# - Fill the missing data and the outliers using the decided Classifier, Regressor + Data scaling technique. Make sure the rows are properly scaled before you forecast the values<br>

# %% [markdown]
# # Cleaning data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Recency              2240 non-null   int64
#  8   MntMeatProducts      2240 non-null   int64
#  9   MntFishProducts      2240 non-null   int64
#  10  MntSweetProducts     2240 non-null   int64
#  11  MntGoldProds         2240 non-null   int64
#  12  NumDealsPurchases    2240 non-null   int64
#  13  NumWebPurchases      2240 non-null   int64
#  14  NumCatalogPurchases  2240 non-null   int64
# ...

# %% [markdown]
# ## Filling missing values

# %% [markdown]
# Befor removing missing values

# %%
fig, axs = plt.subplots(3,1,figsize=(16,18))
axs = axs.flatten()
df['Income'].iloc[:200].plot(ax=axs[0], title='Income', xlabel='')
df['MntWines'].iloc[:200].plot(ax=axs[1], title='MntWines', xlabel='')
df['MntFruits'].iloc[:200].plot(ax=axs[2], title='MntFruits', xlabel='')

plt.show()

# %%
df['Income']=df['Income'].interpolate(method ='linear',limit_direction ='forward')
df['MntFruits']=df['MntFruits'].interpolate(method ='linear',limit_direction ='forward')

print('after removing missing values of dataset')
# Out:
# after removing missing values of dataset

# %%
df['MntWines']=df['MntWines'].fillna(method="ffill")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2240 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Recency              2240 non-null   int64
#  8   MntMeatProducts      2240 non-null   int64
#  9   MntFishProducts      2240 non-null   int64
#  10  MntSweetProducts     2240 non-null   int64
#  11  MntGoldProds         2240 non-null   int64
#  12  NumDealsPurchases    2240 non-null   int64
#  13  NumWebPurchases      2240 non-null   int64
#  14  NumCatalogPurchases  2240 non-null   int64
# ...

# %% [markdown]
# After removing missing values

# %%
fig, axs = plt.subplots(3,1,figsize=(16,18))
axs = axs.flatten()
df['Income'].iloc[:200].plot(ax=axs[0], title='Income', xlabel='')
df['MntWines'].iloc[:200].plot(ax=axs[1], title='MntWines', xlabel='')
df['MntFruits'].iloc[:200].plot(ax=axs[2], title='MntFruits', xlabel='')

plt.show()

# %% [markdown]
# ## Removing outliers

# %%
print('rows of data set befor removing outliers: ',df.shape)
# Out:
# rows of data set befor removing outliers:  (2240, 22)

# %%
cols = df.columns#['Income', 'MntMeatProducts','MntSweetProducts'] # one or more

Q1 = df[cols].quantile(0.05)
Q3 = df[cols].quantile(0.95)
IQR = Q3 - Q1

df_b = df[~((df[cols] < (Q1 - 1.5 * IQR)) |(df[cols] > (Q3 + 1.5 * IQR))).any(axis=1)]
print('shape of dataset after removing outliers',df_b.shape)
# Out:
# shape of dataset after removing outliers (2204, 22)

# %%
df_b['Response'].sum()
# Out:
# 331

# %%
ds_object=pd.DataFrame(df_b, columns=['Education','Marital_Status','Country'])

ds_object
# Out:
#        Education Marital_Status Country
# 0     Graduation       Divorced      SP
# 1     Graduation         Single      CA
# 2     Graduation        Married      US
# 3     Graduation       Together     AUS
# 4     Graduation         Single      SP
# ...          ...            ...     ...
# 2235         PhD       Divorced      US
# 2236    2n Cycle        Married      SP
# 2237  Graduation       Divorced      SP
# 2238  Graduation        Married     IND
# 2239         PhD        Married      CA
#
# [2204 rows x 3 columns]

# %%
df_non_object=df_b.drop(['Education','Marital_Status','Country'],axis=1)

# %%
print()
print('            Boxplot and Hist diagram of some attributes before filling missing values and removing outliers')


plt.figure(figsize=(12,16),dpi=100)


ax=plt.subplot(4,2,1)
sns.boxplot(y=df_non_object['Income'])
ax.set_xlabel('Income')
ax=plt.subplot(4,2,2)
sns.histplot(data=df_non_object,x=df_non_object['Income'])


ax=plt.subplot(4,2,3)
sns.boxplot(y=df_non_object['MntWines'])
ax.set_xlabel('MntWines')
ax=plt.subplot(4,2,4)
sns.histplot(data=df_non_object,x=df_non_object['MntWines'])

ax=plt.subplot(4,2,5)
sns.boxplot(y=df_non_object['MntMeatProducts'])
ax.set_xlabel('MntMeatProducts')
ax=plt.subplot(4,2,6)
sns.histplot(data=df_non_object,x=df_non_object['MntMeatProducts'])

ax=plt.subplot(4,2,7)
sns.boxplot(y=df_non_object['MntSweetProducts'])
ax.set_xlabel('MntSweetProducts')
ax=plt.subplot(4,2,8)
sns.histplot(data=df_non_object,x=df_non_object['MntSweetProducts'])


plt.subplots_adjust(wspace=1.6)
plt.subplots_adjust(hspace=0.2)

plt.show()
# Out:
#             Boxplot and Hist diagram of some attributes before filling missing values and removing outliers

# %%
print('rows of data set befor removing outliers: ',df_non_object.shape)
# Out:
# rows of data set befor removing outliers:  (2204, 19)

# %% [markdown]
# ## Dataset after proprocessing

# %% [markdown]
# convert object attributes to numeric

# %%
list=['Education','Marital_Status','Country']
df_b=pd.get_dummies(df_b,columns=list,prefix=list)

# %% [markdown]
# Final shape of dataset before training

# %%
df_b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2204 entries, 0 to 2239
# Data columns (total 40 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       2204 non-null   int64
#  1   Year_Birth               2204 non-null   int64
#  2   Income                   2204 non-null   float64
#  3   Kidhome                  2204 non-null   int64
#  4   Teenhome                 2204 non-null   int64
#  5   Recency                  2204 non-null   int64
#  6   MntMeatProducts          2204 non-null   int64
#  7   MntFishProducts          2204 non-null   int64
#  8   MntSweetProducts         2204 non-null   int64
#  9   MntGoldProds             2204 non-null   int64
#  10  NumDealsPurchases        2204 non-null   int64
#  11  NumWebPurchases          2204 non-null   int64
#  12  NumCatalogPurchases      2204 non-null   int64
#  13  NumStorePurchases        2204 non-null   int64
# ...

# %% [markdown]
# ## training dataset

# %%
#train_set=abalone.drop('Response',axis=1)
x=df_b.drop('Response',axis=1)
y=df_b['Response']

X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=.2, random_state=seed)

print('shape of train set is:      ',X_train.shape)
print('shape of train label set is:',y_train.shape)
print()
print('shape of test set is:       ',X_test.shape)
print('shape of test label set is: ',y_test.shape)
# Out:
# shape of train set is:       (1763, 39)
# shape of train label set is: (1763,)
#
# shape of test set is:        (441, 39)
# shape of test label set is:  (441,)

# %%
lin_model = SGDClassifier(loss="squared_error", penalty="l2", max_iter=500)

cv = RepeatedKFold(n_splits=10, n_repeats=5, random_state=1)
knn_model = KNeighborsClassifier(n_neighbors=3)
knn_scores = cross_val_score(knn_model, x, y, scoring='f1_weighted', cv=cv, n_jobs=-1)

# %%
print("Accuracy:    {:.2f}".format( knn_scores.mean()*100))
# Out:
# Accuracy:    79.34

# %% [markdown]
# Base line model

# %%
scaler_Min = Normalizer()
X_train1 = scaler_Min.fit_transform(X_train)
X_test1 = scaler_Min.fit_transform(X_test)

sgdc = SGDClassifier()
sgdc.fit(X_train1, y_train)
score = sgdc.score(X_test1, y_test)
y_pred=sgdc.predict(X_test1)
f1=f1_score(y_test,y_pred, average='weighted')
print("Accuracy:    {:.2f}".format( score*100))
print("F1_Score:    {:.2f}   ".format( f1*100))
# Out:
# Accuracy:    86.17
# F1_Score:    79.77

# %% [markdown]
# combination of sclaing technioques with KNN and SGD

# %%
models = [KNeighborsClassifier(n_neighbors=5), SGDClassifier(loss='hinge', penalty='l2', max_iter=1000)]
models_names = ['KNN', 'SGD']
scalers = [None, MinMaxScaler(), Normalizer(), MaxAbsScaler(), RobustScaler(),
           QuantileTransformer(n_quantiles=5, random_state=seed, output_distribution='normal')]

scalers_names = ['Raw data', 'MinMax', 'Z-score', 'MaxAbs', 'Robust', 'Quantile']

fig, axs = plt.subplots(figsize=(8,6),dpi=100)
results = {}
for j in range(len(models)):
    for k in range(len(scalers)):
        if scalers[k]:
            X_scaled = scalers[k].fit_transform(x)
        else:
            X_scaled = x
        cv = RepeatedKFold(n_splits=5, n_repeats=10, random_state=seed)
        scores = cross_val_score(models[j], X_scaled, y, scoring='accuracy', cv=cv, n_jobs=-1)
        results[f'{models_names[j]}-{scalers_names[k]}'] = scores

df_res = pd.DataFrame(results).copy()
df_res.boxplot(rot=45)
axs.set_ylabel("Accuracy")
plt.xticks(ha='right')
plt.show()

# %% [markdown]
# Fill the missing data and the outliers using the decided Classifier, Regressor + Data scaling technique. Make sure the rows are properly scaled before you forecast the values

# %%
from sklearn.impute import KNNImputer
train_knn = df_hist.copy(deep=True)

knn_imputer = KNNImputer(n_neighbors=2, weights="uniform")
train_knn['MntFruits'] = knn_imputer.fit_transform(train_knn[['MntFruits']])
train_knn['MntWines'] = knn_imputer.fit_transform(train_knn[['MntWines']])

train_knn['MntFruits'].isnull().sum()
train_knn['MntWines'].isnull().sum()
# Out:
# 0

# %% [markdown]
# <font size='6'>$\color{red}{\text{Task 4}}$

# %% [markdown]
# <font size='3.5'>
# - In the fourth part of your project , you can choose between two paths, (1) solve a feature selection problem or
#    (2) perform data encoding to try to enhance the performance of a classifier.<br><br>
#     - We choosed feature selection<br>
#
#
#
# - Define a target value to forecast (either a classification or a regression task).<br>
#     - Target value is defined<br>
#
# - Select two feature selection techniques and justify why you chose them.<br>
#     - 3 feature selection techniques selected and tested<br>
#     - Because our first features are continuous and our response is categorical, the best feature technique is chi-square. We can observe this hypothesis by comparing this feature selection with f_classif and mutual_into_classif. We start to select sets of best features by different scoring functions and fit to models with cross validation. Also we have plotted the distribution of accuracy of these combinations<br>
#
# - There are 6 combinations of scoring function and classifier in total:<br>
#     - Scoring functions: chi2, f_classif, mutual_info_classif<br>
#     - Classifiers: SVC, RandomForestClassifier
#
# - Define as baseline model using all features and store its performance. You must consider using a repeated cross-validation to generate several estimates. You may want to choose as your selected model the one with best performance in Part 3.<br>
#     - selected<br>
#
# - Apply the feature selection techniques and compare their performance with the baseline. Are there improvements? Yes, no, why? Try to discuss your outcomes.<br>
#     - yes there are improvment in term of accuracy because of effect of scaling

# %%
knn=KNeighborsClassifier(n_neighbors=5)
sgd=SGDClassifier(loss='hinge', penalty='l2', max_iter=1000)

sel = SelectKBest()
scaler = MinMaxScaler()  # only for svm classification
classifier = [knn ,sgd]
score_function = [chi2,f_classif,mutual_info_classif]
cv = RepeatedKFold(n_splits=5, n_repeats=10, random_state=321)

k_best = [5, 10, 15, 20,25,30]

# You must write your code starting from here
def select_features(X, y, score_function,k_best):
      sel = SelectKBest(score_func=score_function, k=k_best).fit_transform(x, y)
      return sel
a=[]
b=[]
c=[]
d=[]
e=[]
f=[]
for i in k_best:
    X_chi = select_features(x,y,score_function[0],k_best=i)
    X_fs= select_features(x,y,score_function[1],k_best=i)
    X_mic= select_features(x,y,score_function[2],k_best=i)
    x_scaler = scaler.fit_transform(x)
    X_chi_svc = select_features(x_scaler,y,score_function[0],k_best=i)
    X_fs_svc = select_features(x_scaler,y,score_function[1],k_best=i)
    X_mic_svc = select_features(x_scaler,y,score_function[2],k_best=i)

    scores1 = cross_val_score(sgd, X_chi,y, cv=cv, n_jobs=-1)
    scores2 = cross_val_score(sgd, X_fs,y, cv=cv, n_jobs=-1)
    scores3 = cross_val_score(sgd, X_mic,y, cv=cv, n_jobs=-1)
    scores4 = cross_val_score(knn, X_chi_svc,y, cv=cv, n_jobs=-1)
    scores5 = cross_val_score(knn, X_fs_svc, y, cv=cv, n_jobs=-1)
    scores6 = cross_val_score(knn, X_mic_svc, y, cv=cv, n_jobs=-1)
    a.append(scores1)
    b.append(scores2)
    c.append(scores3)
    d.append(scores4)
    e.append(scores5)
    f.append(scores6)

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, axs = plt.subplots(2, 3,figsize=(14,14),dpi=200)
axs = axs.flatten()

#plt.label("Number of features selected")

axs[0].boxplot(d)
axs[0].set_title('knn_chi2')
axs[0].set_xlabel('K_best feature')
axs[0].set_ylabel("accuracy")
axs[1].boxplot(e)
axs[1].set_title('knn_fs')
axs[1].set_xlabel('K_best feature')
axs[1].set_ylabel("accuracy")
axs[2].boxplot(f)
axs[2].set_title('knn_mi')
axs[2].set_xlabel('K_best feature')
axs[2].set_ylabel("accuracy")
axs[3].boxplot(a)
axs[3].set_title('sgd_chi2')
axs[3].set_xlabel('K_best feature')
axs[3].set_ylabel("accuracy")
axs[4].boxplot(b)
axs[4].set_title('sgd_fs')
axs[4].set_xlabel('K_best feature')
axs[4].set_ylabel("accuracy")
axs[5].boxplot(c)
axs[5].set_title('sgd_mi')
axs[5].set_xlabel('K_best feature')
axs[5].set_ylabel("accuracy")
plt.show()

# %% [markdown]
# Feature selection using RFECV

# %%
#train_set=abalone.drop('Response',axis=1)
x=df_b.drop('Response',axis=1)
y=df_b['Response']

X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=.2, random_state=seed)

print('shape of train set is:      ',X_train.shape)
print('shape of train label set is:',y_train.shape)
print()
print('shape of test set is:       ',X_test.shape)
print('shape of test label set is: ',y_test.shape)
# Out:
# shape of train set is:       (1763, 39)
# shape of train label set is: (1763,)
#
# shape of test set is:        (441, 39)
# shape of test label set is:  (441,)

# %%
from sklearn.feature_selection import RFECV

estimator =SGDClassifier(loss='hinge', penalty='l2', max_iter=1000)

rfecv = RFECV(estimator, step=1, cv=5)
rfecv = rfecv.fit(X_train, y_train)

# %%
svc = SVC(kernel="linear")

from sklearn.feature_selection import RFECV
import matplotlib.pyplot as plt

rfecv = RFECV(estimator=svc, step=1, cv=5, scoring='accuracy')   #5-fold cross-validation

rfecv = rfecv.fit(x_scaler, y)
X_chi = select_features(x,y,score_function[1],k_best[5])
# print(rfecv.grid_scores_)
rfecv2 = RFECV(estimator=sgd, step=1, cv=5, scoring='accuracy')   #5-fold cross-validation
rfecv2 = rfecv2.fit(x_scaler, y)

fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(10,4))
res_mean = []
res2_mean = []
for i in rfecv.grid_scores_:
    res_mean.append(sum(i)/len(i))
for j in rfecv2.grid_scores_:
    res2_mean.append(sum(j)/len(j))
col = (0.85,0.85,0.85)

ax1.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_,color = col);
ax1.plot(range(1,len(res_mean) +1),res_mean,"r-");
ax1.set_title('RFE with SVM classifier')
ax1.set_xlabel("Number of features selected")
ax1.set_ylabel("accuracy")
ax2.plot(range(1, len(rfecv2.grid_scores_) + 1), rfecv2.grid_scores_,color = col);
ax2.plot(range(1,len(res2_mean) +1),res2_mean,"b-");
ax2.set_title('RFE with SGD classifier')
ax2.set_xlabel("Number of features selected")
ax2.set_ylabel("accuracy")
plt.tight_layout()
plt.show()

# %%
best = rfecv2.get_feature_names_out()
print("The total number of best features are: %d" %len(best))
print("The best features from SVM classifier are: ")
for i in best :
    print(i)
# Out:
# The total number of best features are: 18
# The best features from SVM classifier are:
# x2
# x4
# x5
# x6
# x7
# x9
# x10
# x11
# x12
# x13
# x14
# x16
# x19
# x23
# x26
# x28
# x34
# x35

# %% [markdown]
# <center><font size='4'>$\color{red}{\text{Thank you so much Professor}}$ <br>
# Best Regards,<br>Bahre Zare - Mahmoud Maheri
